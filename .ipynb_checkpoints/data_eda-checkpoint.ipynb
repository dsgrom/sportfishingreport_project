# %% [markdown]
# # Plan
#
# ## First thing's first, some additional cleaning while exploring some of the data
# 1. (DONE) drop redundant columns
#
# 2. (DONE) 'restrictions_yn' binary 0 for Na's (no restrictions), 1 for has restrictions. Restrictions were given in species descriptions and counts based on weight (i.e. 'up to 30 pounds' or something)
#
# 3. (DONE, EXPLANATION UNDERNEATH NEEDED) descriptive stats for numerical variables
#
#    a. should I change 'restrictions' column to binary 0 and 1? or just the weight int? probs need to change though
#
# 4. look at categorical variables' value_counts(), see if I can recategorize any to lower amt of unique elements
#
#    a. (DONE) location (removed 4 categories with low volume and relevancy)
#
#    b. boat_name (not yet sure how to handle, might just drop entirely)
#
#    c. (DONE) trip_type
#
# 5. (DONE for now) catch_species:
#
#    a. (DONE) misnamed/mistyped common names, need to merge
#
#    b. (DONE) generalizing species (i.e. all sharks, all rockfish...)
#
# ## Questions worth answering
# 1. What are the most popular species by:
#
#     a. trip type?
#
#     b. location?
#
#     c. boat name?
#
#     d. time of year (month)?
#
#     e. combos, i.e. location and trip type, such as 3/4 trips out of San Diego?
#
# 2. are catches across locations correlated?
#
# 3. can we predict how many fish of any given species will be caught each month in each location?
#
# 4. can we predict how many fish will be released in any given month in each location?

# %%
#import packages and set wd to sportfishingreport_project folder
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

os.chdir("C:/Users/Kevin/Documents/Projects/Portfolio/sportfishingreport_project")

# %%
#read in data
df_raw = pd.read_csv("sfr_data_cleaned.csv")
df = df_raw.copy()

# %%
#overview of first 3 columns
print(df.head(3), '\n')
print('Dataframe dimensions: ', df.shape, '\n')
print('Column types:', '\n', df.dtypes, sep = '')
# Out:
#          date       location    boat_name      trip_type num_anglers  \
# 0  2020-01-01  central coast  new horizon  full day trip  12 Anglers
# 1  2020-01-01  central coast  new horizon  full day trip  12 Anglers
# 2  2020-01-01    los angeles   native sun   3/4 day trip  21 Anglers
#
#                                                catch  trip_num       date2  \
# 0                     23 Dungeness Crab, 215 Sanddab         1  2020-01-01
# 1                     23 Dungeness Crab, 215 Sanddab         1  2020-01-01
# 2  25 Sand Bass, 65 Blacksmith, 1 Halibut, 15 Scu...         1  2020-01-01
#
#    year  month  day day_of_week  anglers  released restrictions  catch_count  \
# 0  2020      1    1   Wednesday       12         0          NaN         23.0
# 1  2020      1    1   Wednesday       12         0          NaN        215.0
# 2  2020      1    1   Wednesday       21         0          NaN         25.0
#
#     catch_species
# 0  dungeness crab
# 1         sanddab
# 2       sand bass
#
# Dataframe dimensions:  (63293, 17)
#
# Column types:
# date              object
# location          object
# boat_name         object
# trip_type         object
# num_anglers       object
# catch             object
# trip_num           int64
# date2             object
# year               int64
# month              int64
# day                int64
# day_of_week       object
# anglers            int64
# released           int64
# restrictions      object
# catch_count      float64
# catch_species     object
# dtype: object

# %%
#drop redundant columns
df = df.drop(['date', 'catch', 'num_anglers'], axis = 1)
df['restrictions_yn'] = df['restrictions'].apply(lambda x: 1 if pd.notnull(x) else 0)

# %%
#column names
df.columns
# Out:
# Index(['location', 'boat_name', 'trip_type', 'trip_num', 'date2', 'year',
#        'month', 'day', 'day_of_week', 'anglers', 'released', 'restrictions',
#        'catch_count', 'catch_species', 'restrictions_yn'],
#       dtype='object')

# %% [markdown]
# ## LOCATION CLEANING
#
# ### Can I recategorize or remove any?

# %%
#look at categorical columns to see unique values and # instances
df.location.value_counts()
# Out:
# san diego           18907
# los angeles         11559
# ventura coast       10277
# orange               9872
# central coast        6425
# bay area             5293
# washington coast      473
# north coast           210
# oregon coast          201
# delta                  37
# lake tahoe             36
# puget sound             2
# florida south           1
# Name: location, dtype: int64

# %%
#remove the florida south, puget sound, lake tahoe, and delta ones since there's so little data
location_list = ['florida south', 'puget sound', 'delta', 'lake tahoe']
df.drop(df.loc[df['location'].isin(location_list)].index, inplace = True) #removes rows

# %%
#double check to make sure rows were deleted
df.location.value_counts()
# Out:
# san diego           18907
# los angeles         11559
# ventura coast       10277
# orange               9872
# central coast        6425
# bay area             5293
# washington coast      473
# north coast           210
# oregon coast          201
# Name: location, dtype: int64

# %%
#yep removed 80 rows
print(df.shape)
# Out:
# (63217, 15)

# %% [markdown]
# ## trip_type CLEANING
#
# ### Can I recategorize or remove any?

# %%
#trip types, pretty hard to ideentify if trips are the same type or not
#ex: 3/4 day local vs 3/4 day islands vs 3/4 day trip, all 3/4 (probs SD trips too)
#targetting different species based on location, so should they be categorized together or not?
#trip_type counts drastically drop off after 3/4 day trip, though expected that there are less
#overnight and greater trips
df.trip_type.value_counts()
# Out:
# 1/2 day trip             21600
# full day trip            15952
# 3/4 day trip             14487
# overnight trip            6254
# 1.5 day trip              1866
# 2 day trip                1114
# 2.5 day trip               744
# 12 hour                    246
# salmon trolling            234
# 3 day trip                 196
# 3.5 day trip               119
# 1.75 day trip              117
# crab combo                  73
# 5 hour                      42
# 3/4 day islands             27
# 7 hour                      18
# extended 1.5 day trip       17
# dungeness crab              10
# 3/4 day local                9
# 5 day trip                   9
# 4 day trip                   7
# crab                         7
# lobster                      5
# 6 hour                       3
# 4 hour                       3
# 8 hour                       2
# salmon mooching              2
# 2.75 day trip                2
# halibut                      1
# dungeness crab am            1
# salmon                       1
# offshore halibut             1
# Name: trip_type, dtype: int64

# %%
pd.set_option('display.max_rows', 500)

df[['location', 'trip_type']].groupby(['trip_type', 'location']).size().reset_index().rename(columns = {0: 'count'}) \
    .sort_values(['trip_type', 'location'], ascending = [True, True])
# Out:
#                 trip_type          location  count
# 0            1.5 day trip       los angeles    146
# 1            1.5 day trip            orange    103
# 2            1.5 day trip         san diego   1610
# 3            1.5 day trip     ventura coast      7
# 4           1.75 day trip         san diego    117
# 5            1/2 day trip          bay area    238
# 6            1/2 day trip     central coast   3000
# 7            1/2 day trip       los angeles   3909
# 8            1/2 day trip       north coast     37
# 9            1/2 day trip            orange   4903
# 10           1/2 day trip      oregon coast     22
# 11           1/2 day trip         san diego   8386
# 12           1/2 day trip     ventura coast   1086
# 13           1/2 day trip  washington coast     19
# 14                12 hour     central coast    246
# 15             2 day trip       los angeles    109
# 16             2 day trip            orange    114
# 17             2 day trip         san diego    711
# 18             2 day trip     ventura coast    180
# 19           2.5 day trip       los angeles     15
# 20           2.5 day trip         san diego    729
# 21          2.75 day trip         san diego      2
# 22             3 day trip         san diego    160
# 23             3 day trip     ventura coast     36
# 24           3.5 day trip         san diego    119
# 25        3/4 day islands         san diego     19
# 26        3/4 day islands     ventura coast      8
# 27          3/4 day local         san diego      9
# 28           3/4 day trip          bay area      7
# 29           3/4 day trip     central coast   1744
# 30           3/4 day trip       los angeles   4604
# 31           3/4 day trip            orange   2947
# 32           3/4 day trip         san diego   1704
# 33           3/4 day trip     ventura coast   3481
# 34             4 day trip         san diego      7
# 35                 4 hour     central coast      3
# 36             5 day trip         san diego      9
# 37                 5 hour      oregon coast     42
# 38                 6 hour      oregon coast      3
# 39                 7 hour     central coast     18
# 40                 8 hour      oregon coast      2
# 41                   crab          bay area      7
# 42             crab combo          bay area     73
# 43         dungeness crab          bay area     10
# 44      dungeness crab am          bay area      1
# 45  extended 1.5 day trip         san diego     17
# 46          full day trip          bay area   4675
# 47          full day trip     central coast   1414
# 48          full day trip       los angeles   1183
# 49          full day trip       north coast    173
# 50          full day trip            orange    975
# 51          full day trip      oregon coast    130
# 52          full day trip         san diego   3208
# 53          full day trip     ventura coast   3742
# 54          full day trip  washington coast    452
# 55                halibut          bay area      1
# 56                lobster       los angeles      5
# 57       offshore halibut      oregon coast      1
# 58         overnight trip       los angeles   1588
# 59         overnight trip            orange    830
# 60         overnight trip         san diego   2099
# 61         overnight trip     ventura coast   1737
# 62                 salmon          bay area      1
# 63        salmon mooching          bay area      2
# 64        salmon trolling          bay area    234

# %%
#reset display option to default
pd.reset_option('display.max_rows')

# %% [markdown]
# ### Notes from trip_type and location grouping:
#  * 1.5 day trips are CA only (LA, OC, SD, Ventura) 5th largest trip_type
#  * 1/2 day trip is universal across the coast I think (present in all 3 states), largest trip type
#  * 2 day trips are CA only (LA, OC, SD, Ventura) 6th largest trip_type
#  * 2.5 day trip is LA and SD only, LA only 15 of them but 7th largest trip_type so worth keeping
#  * 3/4 day trip is only CA but 3rd largest trip_type
#  * overnight trip (LA, OC, SD, Ventura) only
#  * full day trips are everywhere, second most popular trip
#
# ### Actionable:
#  * x.75 day trips are SD only (only 2 types, 1.75 (122 trips) and 2.75 (2 trips, maybe can delete or round up to 3 day))
#  * 12 hour is ONLY central coast change to full day
#  * 3 day, 3.5 day trips only available in SD and Ventura. Maybe merge anything greater than 2.5 day into one "long" cat? only 7 4 day trips (SD only), 9 5 day trips (SD only)
#  * 4 hour trip is central coast only, only 3 trips (relabel as half day?)
#  * 7 hour trip also only central coast, 18 trips total? can see if this still exists or not, relabel 3/4
#  * 5 hr (42 trips), 6 hr (3 trips), 8 hr (2 trips) all oregon coast only, merge 8 with 3/4 (?) and 5-6 with 1/2 day
#  * extended 1.5 day is SD only, merge with 1.5 day
#  * all crab and salmon trips are bay area only, can probs merge all crab into one and salmon into one
#
# ### Unsure how to handle:
#  * 3/4 island, 3/4 local, and 3/4 day trip - how to handle? Ventura and SD both have "islands" trips, but diff islands
#  * only 2 halibut trip (1 bay area, 1 "offshore halibut" oregon coast), might delete? check on this one
#  * only 5 lobster trip (LA), might delete? check on this one
#
# ### Changes made:
#  * Anything 3+ days is "multi-day trip"
#  * ".75" day trips rounded up (really only applies to a few trips from SD)
#  * "12 hour" trips recoded to "full day trip"
#  * "4 hour", "5 hour", and "6 hour" trips recoded to "1/2 day trip"
#  * "7 hour" and "8 hour" trips recoded to "3/4 day trip"
#  * "3/4 day local" and "3/4 day islands" recoded to "3/4 day trip" because only 36 trips total
#  * "extended 1.5 day trip" recoded to "1.5 day trip" (again only applies to a few trips from SD)
#  * all crab trips recoded to "crabbing trip"
#  * all salmon trips recoded to "salmon trip"
#  * all other species-specific indicating trips recoded to "other trip"

# %%
#function to replace trip_type according to above notes

def trip_type_simplifier(trip_type):
    if trip_type == '2.75 day trip':
        return 'multi-day trip'
    elif trip_type == '1.75 day trip':
        return '2 day trip'
    elif trip_type == '12 hour':
        return 'full day trip'
    #elif trip_type == '4 day trip' or trip_type == '5 day trip':
    elif trip_type in ['3 day trip', '3.5 day trip', '4 day trip', '5 day trip']:
        return 'multi-day trip'
    #elif trip_type == '4 hour' or trip_type == '5 hour' or trip_type == '6 hour':
    elif trip_type in ['4 hour', '5 hour', '6 hour']:
        return '1/2 day trip'
    #elif trip_type == '7 hour' or trip_type == '8 hour':
    elif trip_type in ['7 hour', '8 hour', '3/4 day local', '3/4 day islands']:
        return '3/4 day trip'
    elif trip_type == 'extended 1.5 day trip':
        return '1.5 day trip'
    elif trip_type in ['crab', 'crab combo', 'dungeness crab', 'dungeness crab am']:
        return 'crabbing trip'
    elif trip_type in ['salmon', 'salmon mooching', 'salmon trolling']:
        return 'salmon trip'
    elif trip_type in ['lobster', 'halibut', 'offshore halibut']:
        return 'other trip'
    elif trip_type == None:
        return 'na'
    else:
        return trip_type

# %%
#apply function to trip_type
df['trip_type'] = df['trip_type'].apply(trip_type_simplifier)

# %%
pd.set_option('display.max_rows', 500)

print(df.trip_type.value_counts(), '\n')

print(df[['location', 'trip_type']].groupby(['trip_type', 'location']).size().reset_index().rename(columns = {0: 'count'}) \
    .sort_values(['trip_type', 'location'], ascending = [True, True]))
# Out:
# 1/2 day trip      21648
# full day trip     16198
# 3/4 day trip      14543
# overnight trip     6254
# 1.5 day trip       1883
# 2 day trip         1231
# 2.5 day trip        744
# multi-day trip      333
# salmon trip         237
# crabbing trip        91
# other trip            7
# Name: trip_type, dtype: int64
#
#          trip_type          location  count
# 0     1.5 day trip       los angeles    146
# 1     1.5 day trip            orange    103
# 2     1.5 day trip         san diego   1627
# 3     1.5 day trip     ventura coast      7
# 4     1/2 day trip          bay area    238
# 5     1/2 day trip     central coast   3003
# 6     1/2 day trip       los angeles   3909
# 7     1/2 day trip       north coast     37
# 8     1/2 day trip            orange   4903
# 9     1/2 day trip      oregon coast     67
# 10    1/2 day trip         san diego   8386
# 11    1/2 day trip     ventura coast   1086
# 12    1/2 day trip  washington coast     19
# 13      2 day trip       los angeles    109
# 14      2 day trip            orange    114
# 15      2 day trip         san diego    828
# 16      2 day trip     ventura coast    180
# 17    2.5 day trip       los angeles     15
# 18    2.5 day trip         san diego    729
# 19    3/4 day trip          bay area      7
# 20    3/4 day trip     central coast   1762
# 21    3/4 day trip       los angeles   4604
# 22    3/4 day trip            orange   2947
# 23    3/4 day trip      oregon coast      2
# 24    3/4 day trip         san diego   1732
# 25    3/4 day trip     ventura coast   3489
# 26   crabbing trip          bay area     91
# 27   full day trip          bay area   4675
# 28   full day trip     central coast   1660
# 29   full day trip       los angeles   1183
# 30   full day trip       north coast    173
# 31   full day trip            orange    975
# 32   full day trip      oregon coast    130
# 33   full day trip         san diego   3208
# 34   full day trip     ventura coast   3742
# 35   full day trip  washington coast    452
# 36  multi-day trip         san diego    297
# 37  multi-day trip     ventura coast     36
# 38      other trip          bay area      1
# 39      other trip       los angeles      5
# 40      other trip      oregon coast      1
# 41  overnight trip       los angeles   1588
# 42  overnight trip            orange    830
# 43  overnight trip         san diego   2099
# 44  overnight trip     ventura coast   1737
# 45     salmon trip          bay area    237

# %%
#reset display option to default
pd.reset_option('display.max_rows')

# %% [markdown]
# ## SPECIES CLEANING
#
# ### Are there duplicated species that we can consolidate to lessen the number of unique elements?
#  * multiple types of rockfish are present, can probably consolidate to "rockfish". Or create a new column called rockfish_type (or rockfish_species?) that indicates what type of rockfish, 0 for non-rockfish
#  * couple different types of bass (calico, kelp, sand, barred sand, spotted bay...)
#  * some duplicates (barred sand bass, flounder) that appear in 2 rows of value_counts but seems like they shouldn't?
#  * couple different types of croaker (yellowfin croaker, white croaker...)
#  * salmons (coho, king, chinook...)
#
# ### Typos/alternate names:
#  * (DONE) strip leading/trailing whitespace from catch_species
#  * ROCKFISH:
#          * (DONE) 'vermillion rockfish' should be 'vermilion rockfish' (only 1 'l')
#          * (preemptively done) 'rockcod' and 'rockfish' are the same? check with Noah or Travis
#  * SALMON:
#          * (DONE) 'chinoook salmon' has an extra 'o'
#          * (DONE) chinook changed to king
#  * (DONE) 'california yellowtail' and 'yellowtail' same
#  * (DONE) Mahi mahi changed to dorado
#  * (DONE) 'blacksmith' changed to 'blacksmith perch'
#  * (DONE) 'halfmoon' and 'halfmoon perch' recoded to 'blue perch'
#  * (DONE) 'dungeoness crab' to 'dungeness crab'
#  * (DONE) 'pacific bonito' to 'bonito'
#  * (DONE) 'albacore' to 'albacore tuna'
#  * (DONE) 'dog fish shark' and 'spiny dogfish shark' to 'spiny dogfish shark'
#  * (DONE) 'red rock crab' to 'rock crab'
#  * (DONE) 'salmon grouper' to 'bocaccio'
#  * (DONE) 'bolina' to 'greenspotted rockfish'
#  * (DONE) 'ocean whitefish' to 'whitefish'
#  * (DONE) 'spanish jack' to 'jack mackerel' NOT SURE ABOUT HOW TO CATEGORIZE THESE BAITFISH
#  * (DONE) 'spanish mackerel' to 'mackerel' NOT SURE ABOUT HOW TO CATEGORIZE THESE BAITFISH
#  * (DONE) 'giant seabass' mapped to 'black seabass'
#
# ### Generalizations:
#  * All rockfish to "rockfish", including bocaccio, bolina, and treefish
#  * All salmon to "salmon" (except salmon grouper, idk what this is yet)
#  * All basses to "bass" (excl. white seabass, black seabass, other huge basses)
#  * All halibut to "halibut" (Pacific, California, unspecified)
#  * All crab to "crab"
#  * All perch to "perch"
#  * All sharks to "shark"
#  * All tuna to "tuna" (should include yellowfin, bluefin, skipjack, albacore, bigeye)
#  * All marlin and swordfish to "billfish"
#  * All mackerel and jacks to "baitfish"
#
#
# ### Possible to-do:
#  * create new column to generalize species
#  * might be interesting to create new column about species' preferred habitat but not sure
#
# ### Unsure how to handle?
#  * bigger seabasses
#          * black seabass (19 instances)
#          * lots of white seabass in separate category, don't think should merge because black is endangered/illegal to keep I believe
#  * croakers
#          * black croaker (34 instances)
#          * white croaker (4 instances)
#          * yellowfin croaker (1 instance)
#  * sole/flounder? not sure if flounder here refers to sole or not on sportboats...
#          * petrale sole
#          * sand sole (is this a sanddab...? or flounder??)
#          * starry flounder (4 instances)
#          * flounder (2 instances)
#  * other?
#          * opaleye (49 instances)
#          * sargo (34 instances)
#          * white sturgeon (13 instances)
#          * kelp greenling (5 instances)
#          * bonefish (1 instance)
#          * opah (1 instance)
#          * wolf eel (9), bat ray (2), octopus (1), diamond turbot (1)

# %%
#fixing typos first
def species_typo_fixer(catch_species):
    #fish
    if 'rockcod' in catch_species:
        return catch_species.replace('rockcod', 'rockfish')
    elif 'vermillion' in catch_species:
        return catch_species.replace('vermillion', 'vermilion')
    elif catch_species == 'salmon grouper':
        return 'bocaccio'
    elif catch_species == 'kelp bass':
        return 'calico bass'
    elif catch_species == 'barred sand bass':
        return 'sand bass'
    elif catch_species == 'blacksmith':
        return 'blacksmith perch'
    elif 'halfmoon' in catch_species:
        return 'blue perch'
    elif catch_species == 'ocean whitefish':
        return 'whitefish'
    elif catch_species in ['chinook salmon', 'chinoook salmon']:
        return 'king salmon'
    elif catch_species == 'mahi mahi':
        return 'dorado'
    elif catch_species == 'california yellowtail':
        return 'yellowtail'
    elif 'bonito' in catch_species:
        return 'bonito'
    elif 'albacore' in catch_species:
        return 'albacore tuna'
    elif catch_species == 'giant seabass':
        return 'black seabass'
    #not sure about these two
    elif catch_species == 'spanish jack':
        return 'jack mackerel'
    elif catch_species == 'spanish mackerel':
        return 'mackerel'
    
    #crab
    elif catch_species == 'dungeoness crab':
        return 'dungeness crab'
    elif catch_species == 'red rock crab':
        return 'rock crab'
    
    #shark
    elif 'dog' in catch_species:
        return 'spiny dogfish shark'
    
    else:
        return catch_species

# %%
#strip leading/trailing whitespace from catch_species
#df_test = df.copy() #for testing purposes
df.catch_species = df.catch_species.apply(lambda x: x.strip() if pd.notnull(x) else x)

#run catch_species through typo fixer
df['catch_species'] = df['catch_species'].apply(lambda x: species_typo_fixer(x) if pd.notnull(x) else x)

pd.set_option('display.max_rows', 500)
print(df.catch_species.value_counts())
# Out:
# rockfish               9148
# calico bass            6989
# whitefish              5387
# sheephead              4443
# sculpin                4296
# yellowtail             3787
# lingcod                3742
# sand bass              2869
# bonito                 2462
# yellowfin tuna         1821
# bluefin tuna           1785
# barracuda              1744
# king salmon            1645
# red rockfish           1428
# dorado                 1322
# halibut                 981
# bocaccio                954
# copper rockfish         895
# blue perch              853
# vermilion rockfish      706
# dungeness crab          644
# skipjack tuna           609
# sanddab                 418
# white seabass           394
# lobster                 373
# california halibut      353
# striped bass            338
# blacksmith perch        313
# bolina                  256
# cabezon                 248
# triggerfish             235
# rock sole               202
# red snapper             182
# treefish                 98
# mackerel                 95
# yellowtail rockfish      89
# petrale sole             87
# rock crab                77
# pacific halibut          73
# canary rockfish          72
# perch                    55
# black rockfish           50
# opaleye                  49
# silver salmon            47
# sargo                    35
# black croaker            33
# mako shark               27
# black seabass            21
# brown rockfish           20
# pacific mackerel         20
# albacore tuna            19
# coho salmon              16
# blue rockfish            15
# white sturgeon           13
# leopard shark            13
# striped marlin           11
# sand sole                10
# wolf eel                  9
# rubberlip seaperch        9
# spider crab               8
# jack mackerel             8
# thresher shark            8
# kelp greenling            5
# white croaker             4
# starry flounder           4
# soupfin shark             4
# seven gill shark          3
# bigeye tuna               3
# blue marlin               3
# flounder                  2
# spiny dogfish shark       2
# bat ray                   2
# swordfish                 2
# china rockfish            1
# diamond turbot            1
# widow rockfish            1
# quillback rockfish        1
# opah                      1
# gopher rockfish           1
# starry rockfish           1
# ocean perch               1
# spotted bay bass          1
# 0                         1
# black seaperch            1
# yellowfin croaker         1
# bonefish                  1
# olive rockfish            1
# octopus                   1
# Name: catch_species, dtype: int64

# %%
#function to replace catch_species according to above notes

def species_generalizer(catch_species):
    #fish
    #rockfish
    if 'rockfish' in catch_species:
        return 'rockfish'
    if catch_species in ['bocaccio', 'bolina', 'treefish']: #also rockfish
        return 'rockfish'
    #bass, should not include white and black seabass, other huge basses
    elif catch_species in ['calico bass', 'kelp bass', 'sand bass', 'barred sand bass', 'striped bass', 'spotted bay bass']:
        return 'bass'
    #perch
    elif 'perch' in catch_species:
        return 'perch'
    #salmon
    elif catch_species in ['king salmon', 'silver salmon', 'coho salmon']:
        return 'salmon'
    #halibut
    elif 'halibut' in catch_species:
        return 'halibut'
    #tuna
    elif catch_species in ['yellowfin tuna', 'bigeye tuna', 'bluefin tuna', 'skipjack tuna', 'albacore tuna']:
        return 'tuna'
    #CHECK THIS ONE TO MAKE SURE IT WORKS
    #swordfish and marlin
    elif 'swordfish' in catch_species or 'marlin' in catch_species:
        return 'billfish'
    
    #baitfish
    elif 'mackerel' in catch_species:
        return 'baitfish'

    #sharks
    elif 'shark' in catch_species:
        return 'shark'

    
    #crab
    elif 'crab' in catch_species:
        return 'crab'
    
    #other
    elif catch_species in ['black croaker', 'sargo', 'black seabass', 'billfish', 'white sturgeon', 'sand sole', \
                           'wolf eel', 'kelp greenling', 'white croaker', 'starry flounder', 'flounder', 'bat ray', \
                           'bonefish', 'octopus', 'diamond turbot', 'opah', 'yellowfin croaker']:
        return 'other'

    #to catch others and na's, but wonder if i can replace above with the below as else return other?
    else:
        return catch_species

# %%
#run catch_species through generalizer
df['catch_species_general'] = df['catch_species'].apply(lambda x: species_generalizer(x) if pd.notnull(x) else x)

pd.set_option('display.max_rows', 500)
df.catch_species_gen.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-385c4734c2cf> in <module>
#       1 #run catch_species through generalizer
# ----> 2 df['catch_species_general'] = df['catch_species'].apply(lambda x: species_generalizer(x) if pd.notnull(x) else x)
#       3
#       4 pd.set_option('display.max_rows', 500)
#       5 df.catch_species_gen.value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## FINALLY getting into the exploring part of explorative data analysis!
#
# ### To-do:
# #### Continuous variables:
#
# Only 2 relevant ones: num_anglers, catch_count. Date variables don't need descriptives
#  * Descriptive stats
#  * Histograms
#  * Boxplots
#
# #### Categorical variables:
#
# location, boat_name, trip_type, catch_species

# %%
#descriptive stats for anglers and catch_count
df.anglers.hist()

# %%
df.catch_count.hist()

# %%
#boxplots
df.boxplot(column = 'anglers')

# %%
#catch_count boxplot
df.boxplot(column = 'catch_count')

#there's some weird catch in the thousands rows for some reason, not sure what happened there but that's not true
#delete rows above what threshold?

# %%
#correlation btw continuous variables
df[['catch_count', 'anglers']].corr()
# Out:
#              catch_count   anglers
# catch_count     1.000000  0.095611
# anglers         0.095611  1.000000

# %%
#plotting corr using seaborn, don't need this really for just 2 variables but for future reference
#helpful to visualize correlations, esp because in regressions, important to reduce multicollinearity
cmap = sns.diverging_palette(220, 10, as_cmap = True)
sns.heatmap(df[['catch_count', 'anglers']].corr(), vmax = 0.3, center = 0, cmap = cmap,
            square = True, linewidths = 0.5, cbar_kws = {"shrink": 0.5})

# %%
#categorical data:
df.columns
cat_col = ['location', 'trip_type', 'day_of_week', 'released', 'catch_species', 'catch_species_gen', 'restrictions_yn']

#df with categorical columns only
df_cat = df[cat_col]

# %%
#loop through categorical df to make some exploratory charts

for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for location: total = 9
# graph for trip_type: total = 11
# graph for day_of_week: total = 7
# graph for released: total = 2
# graph for catch_species: total = 88
# graph for catch_species_gen: total = 29
# graph for restrictions_yn: total = 2

# %%
#species plots in more detail
for i in df_cat[['catch_species', 'catch_species_gen']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x = cat_num.index, y = cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation = 90)
    plt.show()
# Out:
# graph for catch_species: total = 20
# graph for catch_species_gen: total = 20

# %%
#pivot tables
pd.pivot_table(df, index = ['location', 'trip_type'], values = 'catch_count', aggfunc = np.sum)
#help(pd.pivot_table)
# Out:
#                                  catch_count
# location         trip_type
# bay area         1/2 day trip         9226.0
#                  3/4 day trip          288.0
#                  crabbing trip       17082.0
#                  full day trip      291432.0
#                  other trip             17.0
#                  salmon trip          3494.0
# central coast    1/2 day trip       133732.0
#                  3/4 day trip        69525.0
#                  full day trip      104877.0
# los angeles      1.5 day trip         4725.0
#                  1/2 day trip       181656.0
#                  2 day trip           3921.0
#                  2.5 day trip          611.0
#                  3/4 day trip       224198.0
#                  full day trip       38916.0
#                  other trip            111.0
#                  overnight trip      63104.0
# north coast      1/2 day trip         2478.0
#                  full day trip        4139.0
# orange           1.5 day trip         3403.0
#                  1/2 day trip       108701.0
#                  2 day trip           5862.0
#                  3/4 day trip       103752.0
#                  full day trip       21649.0
#                  overnight trip      24825.0
# oregon coast     1/2 day trip         1281.0
#                  3/4 day trip           34.0
#                  full day trip        5947.0
#                  other trip             11.0
# san diego        1.5 day trip        49062.0
#                  1/2 day trip       208646.0
#                  2 day trip          34657.0
#                  2.5 day trip        32883.0
#                  3/4 day trip        42954.0
#                  full day trip       81666.0
#                  multi-day trip      16661.0
#                  overnight trip      51293.0
# ventura coast    1.5 day trip          158.0
#                  1/2 day trip        77058.0
#                  2 day trip          13348.0
#                  3/4 day trip       280505.0
#                  full day trip      106044.0
#                  multi-day trip       4679.0
#                  overnight trip     109426.0
# washington coast 1/2 day trip          642.0
#                  full day trip       20681.0

# %% [markdown]
# ## Questions worth answering
#
# 1. What are the most productive (by species):
#
#     a. trip type?
#     b. location?
#     c. boat name?
#     d. time of year (month)?
#     e. combos, i.e. location and trip type, such as 3/4 trips out of San Diego?
#
# 2. are catches across locations correlated?
#
# 3. analysis of ridership (need to group to boat level instead of catch level, otherwise will double count a lot):
#
#     a. which trip type attracts the most anglers?
#     b. which location attracts the most anglers? (adjust by population?)
#     c. which time of year attracts the most anglers? in each region?
#
# 3. can we predict how many fish of any given species will be caught each month in each location?
#
# 4. can we predict how many fish will be released in any given month in each location?

# %%
#iterate through list of pivot tables to answer Q1, catch only. ignore number of anglers for now

df_pivots = df[['catch_count', 'catch_species', 'catch_species_gen', 'location', 'trip_type', \
             'month', 'year', 'day_of_week', 'released', 'restrictions_yn', 'restrictions']]

#interative pivot tables
for i in df_pivots.iloc[:, 1:].columns:
        print(i)
        print(pd.pivot_table(df_pivots, index = i, values = 'catch_count', aggfunc = np.sum) \
              .sort_values('catch_count', ascending = False), '\n\n\n')
# Out:
# catch_species
#                      catch_count
# catch_species
# rockfish                984808.0
# whitefish               294918.0
# calico bass             208491.0
# sanddab                 135326.0
# sculpin                 133530.0
# bonito                  107156.0
# dungeness crab           94058.0
# yellowtail               85554.0
# red rockfish             71588.0
# yellowfin tuna           62513.0
# bluefin tuna             43304.0
# dorado                   40268.0
# sand bass                29133.0
# vermilion rockfish       28784.0
# lingcod                  27975.0
# sheephead                25899.0
# king salmon              21633.0
# barracuda                20495.0
# bocaccio                 16681.0
# skipjack tuna            16175.0
# blacksmith perch         14468.0
# blue perch               14260.0
# copper rockfish          12928.0
# halibut                   9590.0
# lobster                   9315.0
# yellowtail rockfish       9173.0
# bolina                    6612.0
# california halibut        5387.0
# red snapper               4792.0
# mackerel                  4336.0
# striped bass              4195.0
# perch                     4065.0
# white seabass             3689.0
# black rockfish            1857.0
# albacore tuna             1467.0
# canary rockfish            879.0
# pacific halibut            727.0
# treefish                   683.0
# triggerfish                654.0
# pacific mackerel           649.0
# rock crab                  512.0
# cabezon                    499.0
# rock sole                  440.0
# silver salmon              435.0
# brown rockfish             293.0
# sand sole                  220.0
# petrale sole               206.0
# coho salmon                173.0
# opaleye                    164.0
# black croaker              101.0
# blue rockfish               85.0
# spider crab                 58.0
# sargo                       55.0
# kelp greenling              54.0
# widow rockfish              50.0
# gopher rockfish             40.0
# black seabass               36.0
# jack mackerel               33.0
# seven gill shark            30.0
# white sturgeon              28.0
# mako shark                  27.0
# starry rockfish             26.0
# rubberlip seaperch          16.0
# leopard shark               14.0
# striped marlin              11.0
# white croaker               11.0
# olive rockfish              10.0
# wolf eel                    10.0
# thresher shark               8.0
# black seaperch               7.0
# spotted bay bass             5.0
# starry flounder              4.0
# soupfin shark                4.0
# ocean perch                  4.0
# bigeye tuna                  3.0
# flounder                     3.0
# blue marlin                  3.0
# bat ray                      2.0
# yellowfin croaker            2.0
# quillback rockfish           2.0
# swordfish                    2.0
# spiny dogfish shark          2.0
# bonefish                     1.0
# opah                         1.0
# china rockfish               1.0
# diamond turbot               1.0
# octopus                      1.0
# 0                            1.0
#
#
#
# catch_species_gen
#                    catch_count
# catch_species_gen
# rockfish             1134500.0
# whitefish             294918.0
# bass                  241824.0
# sanddab               135326.0
# sculpin               133530.0
# tuna                  123462.0
# bonito                107156.0
# crab                   94628.0
# yellowtail             85554.0
# dorado                 40268.0
# perch                  32820.0
# lingcod                27975.0
# sheephead              25899.0
# salmon                 22241.0
# barracuda              20495.0
# halibut                15704.0
# lobster                 9315.0
# baitfish                5018.0
# red snapper             4792.0
# white seabass           3689.0
# triggerfish              654.0
# other                    530.0
# cabezon                  499.0
# rock sole                440.0
# petrale sole             206.0
# opaleye                  164.0
# shark                     85.0
# billfish                  16.0
# 0                          1.0
#
#
#
# location
#                   catch_count
# location
# ventura coast        591218.0
# san diego            517829.0
# los angeles          517242.0
# bay area             323856.0
# central coast        308134.0
# orange               268192.0
# washington coast      21334.0
# oregon coast           7287.0
# north coast            6617.0
#
#
#
# trip_type
#                 catch_count
# trip_type
# 1/2 day trip       723420.0
# 3/4 day trip       721256.0
# full day trip      675351.0
# overnight trip     248648.0
# 2 day trip          57788.0
# 1.5 day trip        57348.0
# 2.5 day trip        33494.0
# multi-day trip      21340.0
# crabbing trip       17082.0
# salmon trip          3494.0
# other trip            139.0
#
#
#
# month
#        catch_count
# month
# 7         375839.0
# 8         354457.0
# 9         337738.0
# 10        336205.0
# 11        303086.0
# 6         296866.0
# 12        153659.0
# 3         142047.0
# 1         141950.0
# 2         106213.0
# 5          13649.0
#
#
#
# year
#       catch_count
# year
# 2020    2458180.0
# 2021     103529.0
#
#
#
# day_of_week
#              catch_count
# day_of_week
# Saturday        546864.0
# Sunday          541795.0
# Friday          370862.0
# Monday          291706.0
# Thursday        276299.0
# up to 155 pounds            1.0
# up to 46 pounds             1.0
# up to 368 pounds            1.0

# %% [markdown]
# ## NOTES ABOUT ABOVE:
#
# * rockfish are most popular species by volume (makes sense)
# * calico bass are also very popular, I wonder how many they keep vs release?
# * yellowtail 8th most caught species on whole west coast, curious about where it places in socal only? in SD only?
#     * additionally, it's second most caught bigger sportfish after bonito. rockfish and calico I would consider to be smaller sportfish?
#     * when generalizing species, tuna catch is greater than yellowtail catch and bonito catch. interesting!
# * ventura coast caught the most fish total, how about per boat?
#     * SD second, less and less as you go up the coast. what about population adjusted or boat adjusted?
# * 1/2 day caught the most fish (def because most trips and mostly targeting rockfish, easier to pull)
#     * trip type x species pivot would be interesting
# * summer and fall months definitely the most productive.
#     * NOTE: APRIL MISSING BECAUSE 2020 WAS COVID YEAR SO SPORT BOATS SHUT DOWN
#     * probably will be more interesting to look at this over time. But also interesting to see the amount of fish kept in the water due to COVID?
# * weekends are the most productive, Sat Sun Fri (in order), Tue Wd Thu least productive (makes sense)
# * about 5% of fish are released, curious how that changes by species
#
# ## Questions about above:
#
# * where are they catching 'whitefish'??? I didn't think it would be the second highest catch volume
# * keeper vs released ratios by species? by region too?
#
# ## Actions:
#
# * Pretty much need to look at everything with a species split (below)
# * also, would be interesting to look at ridership. Need to figure out how to group by boat to avoid double counting

# %%
#pivoted on species

df_pivots = df[['catch_count', 'catch_species', 'catch_species_gen', 'location', 'trip_type', \
             'month', 'year', 'day_of_week', 'released', 'restrictions_yn', 'restrictions']]

#interative pivot tables
for i in df_pivots.iloc[:, 3:].columns:
        print(i)
        print(pd.pivot_table(df_pivots, index = 'catch_species_gen', columns = i, values = 'catch_count', \
                             aggfunc = np.sum), '\n\n\n')
# Out:
# location
# location           bay area  central coast  los angeles  north coast   orange  \
# catch_species_gen
# 0                       NaN            NaN          NaN          NaN      1.0
# baitfish                7.0         1146.0       1767.0          NaN    110.0
# barracuda               NaN            NaN       9030.0          NaN   3010.0
# bass                 4195.0            6.0      45357.0          NaN  85348.0
# billfish                NaN            NaN          3.0          NaN      NaN
# bonito                  NaN           18.0      52477.0          NaN  36973.0
# cabezon               200.0          162.0         17.0          1.0     21.0
# crab                88888.0         3350.0         50.0        750.0      NaN
# dorado                  NaN            NaN        184.0          NaN    626.0
# halibut             13609.0           58.0        150.0        334.0    118.0
# lingcod             11044.0         3636.0       1258.0        529.0     45.0
# lobster                 NaN            NaN        247.0          NaN      NaN
# opaleye                 NaN            NaN         68.0          NaN     23.0
# other                 251.0           53.0         53.0          NaN    138.0
# perch                   NaN            NaN      13074.0          NaN   4339.0
# petrale sole            NaN          182.0         17.0          4.0      1.0
# red snapper             NaN            NaN       4646.0          NaN    146.0
# rock sole              43.0           71.0         53.0          NaN     16.0
# rockfish           183163.0       286354.0     168839.0       4737.0  51647.0
# salmon              20731.0          261.0          NaN        185.0      NaN
# sanddab              1629.0        11494.0      53270.0          NaN   2954.0
# sculpin                 NaN            1.0      67474.0          NaN  44403.0
# shark                  39.0            NaN         14.0          NaN      8.0
# sheephead               NaN           23.0       7938.0          NaN   4493.0
# triggerfish             NaN            NaN        325.0          NaN     96.0
# tuna                   43.0            NaN       3239.0         77.0   2331.0
# white seabass          14.0            1.0        501.0          NaN     38.0
# whitefish               NaN         1318.0      77370.0          NaN  22691.0
# yellowtail              NaN            NaN       9821.0          NaN   8616.0
#
# location           oregon coast  san diego  ventura coast  washington coast
# catch_species_gen
# 0                           NaN        NaN            NaN               NaN
# baitfish                    NaN     1987.0            1.0               NaN
# barracuda                   NaN     4607.0         3848.0               NaN
# bass                        NaN    87398.0        19520.0               NaN
# billfish                    NaN       13.0            NaN               NaN
# bonito                      NaN    16090.0         1598.0               NaN
# cabezon                    27.0        5.0           58.0               8.0
# crab                     1401.0      189.0            NaN               NaN
# dorado                      NaN    39458.0            NaN               NaN
# halibut                   496.0      231.0          566.0             142.0
# lingcod                   965.0      942.0         5589.0            3967.0
# lobster                     NaN     9068.0            NaN               NaN
# opaleye                     NaN        1.0           72.0               NaN
# other                       2.0       30.0            2.0               1.0
# perch                       NaN    11946.0         3461.0               NaN
# petrale sole                NaN        2.0            NaN               NaN
# red snapper                 NaN        NaN            NaN               NaN
# rock sole                   NaN        4.0          253.0               NaN
# rockfish                 4347.0   120635.0       299924.0           14854.0
# salmon                     49.0        NaN            NaN            1015.0
# sanddab                     NaN     3237.0        62742.0               NaN
# sculpin                     NaN    17381.0         4271.0               NaN
# shark                       NaN       20.0            4.0               NaN
# sheephead                   NaN     4238.0         9207.0               NaN
# triggerfish                 NaN      207.0           26.0               NaN
# tuna                        NaN   116337.0           88.0            1347.0
# white seabass               NaN       35.0         3100.0               NaN
# whitefish                   NaN    17625.0       175914.0               NaN
# yellowtail                  NaN    66143.0          974.0               NaN
#
#
#
# trip_type
# trip_type          1.5 day trip  1/2 day trip  2 day trip  2.5 day trip  \
# catch_species_gen
# 0                           NaN           NaN         NaN           NaN
# baitfish                    NaN         860.0         NaN           NaN
# barracuda                  24.0        6084.0        78.0           1.0
# bass                      933.0      129974.0      2089.0         179.0
# billfish                    3.0           1.0         3.0           1.0
# bonito                   1262.0       16428.0       972.0         192.0
# cabezon                     1.0          59.0         NaN           NaN
# crab                        NaN        9228.0         NaN           NaN
# dorado                   6614.0           4.0      6779.0        7223.0
# halibut                    14.0        1178.0       100.0           NaN
# lingcod                   593.0        1882.0       372.0         102.0
# lobster                     NaN        8836.0         NaN           NaN
# opaleye                     NaN          18.0         NaN           NaN
# other                       NaN         220.0         6.0           1.0
# perch                       NaN       21865.0        83.0           NaN
# petrale sole                NaN          63.0         NaN           NaN
# red snapper                72.0         579.0         NaN           NaN
# rock sole                   NaN          99.0         7.0           NaN
# rockfish                 9789.0      334888.0     15035.0        1576.0
# salmon                      NaN         581.0         NaN           NaN
# sanddab                     NaN       24675.0         NaN           NaN
# sculpin                    39.0       86527.0        15.0           NaN
# shark                       1.0          19.0         NaN           NaN
# sheephead                 394.0        8601.0       533.0          64.0
# triggerfish                 NaN         408.0         NaN           NaN
# tuna                    25315.0           1.0     16592.0       17838.0
# white seabass              14.0          66.0       923.0           NaN
# whitefish                1651.0       69709.0      4109.0          11.0
# yellowtail              10629.0         567.0     10092.0        6306.0
#
# trip_type          3/4 day trip  crabbing trip  full day trip  multi-day trip  \
# catch_species_gen
# 0                           1.0            NaN            NaN             NaN
# baitfish                 3266.0            7.0          873.0             NaN
# barracuda                8737.0            NaN         4570.0             NaN
# bass                    58273.0            NaN        40215.0            94.0
# billfish                    1.0            NaN            5.0             NaN
# bonito                  56684.0            NaN        26633.0            73.0
# cabezon                   126.0            NaN          289.0             3.0
# crab                      364.0        10260.0        74347.0             NaN
# dorado                    171.0            NaN         6471.0          2884.0
# halibut                   475.0            NaN        13232.0            22.0
# lingcod                  3362.0            NaN        18737.0            83.0
# lobster                    25.0            NaN            NaN             NaN
# opaleye                    85.0            NaN           59.0             NaN
# other                      27.0            NaN          268.0             1.0
# perch                    9431.0            NaN         1217.0             NaN
# petrale sole               47.0            NaN           95.0             NaN
# red snapper              1978.0            NaN         1229.0             NaN
# rock sole                  85.0            NaN           90.0             6.0
# rockfish               307521.0         6545.0       354812.0          3947.0
# salmon                      2.0            NaN        18817.0             NaN
# sanddab                 96102.0          270.0        14229.0             NaN
# sculpin                 43714.0            NaN         2881.0             4.0
# shark                      19.0            NaN           42.0             NaN
# sheephead                8467.0            NaN         3647.0            47.0
# triggerfish               147.0            NaN           97.0             NaN
# tuna                      576.0            NaN        27153.0          8296.0
# white seabass              83.0            NaN          305.0            81.0
# whitefish              117843.0            NaN        38662.0          1007.0
# yellowtail               3644.0            NaN        26376.0          4792.0
#
# trip_type          other trip  overnight trip  salmon trip
# catch_species_gen
# 0                         NaN             NaN          NaN
# baitfish                  NaN            12.0          NaN
# barracuda                 NaN          1001.0          NaN
# bass                      NaN          9989.0          NaN
# billfish                  NaN             2.0          NaN
# bonito                    NaN          4912.0          NaN
# cabezon                   NaN            16.0          NaN
# crab                      NaN             9.0          NaN
# dorado                    NaN         10122.0          NaN
# halibut                  28.0           282.0         35.0
# lingcod                   NaN          2630.0         79.0
# lobster                 101.0           353.0          NaN
# opaleye                   NaN             2.0          NaN
# other                     NaN             7.0          NaN
# perch                     NaN           224.0          NaN
# petrale sole              NaN             1.0          NaN
# red snapper               NaN           934.0          NaN
# rock sole                 NaN           153.0          NaN
# rockfish                 10.0         98473.0        609.0
# salmon                    NaN             NaN       2771.0
# sanddab                   NaN            50.0          NaN
# sculpin                   NaN           350.0          NaN
# shark                     NaN             3.0          NaN
# sheephead                 NaN          4146.0          NaN
# triggerfish               NaN             2.0          NaN
# tuna                      NaN         27684.0          NaN
# white seabass             NaN          2217.0          NaN
# whitefish                 NaN         61926.0          NaN
# yellowtail                NaN         23148.0          NaN
#
#
#
# month
# month                   1        2        3       5         6         7   \
# catch_species_gen
# 0                      NaN      NaN      1.0     NaN       NaN       NaN
# baitfish            1266.0   1142.0     78.0     NaN     218.0     323.0
# barracuda              NaN      NaN     16.0    33.0    9113.0    8097.0
# yellowtail          12628.0   10781.0   11314.0   18414.0   10742.0   10606.0
#
# day_of_week        Wednesday
# catch_species_gen
# 0                        NaN
# baitfish               135.0
# barracuda             2394.0
# bass                 28795.0
# billfish                 2.0
# bonito               13539.0
# cabezon                 83.0
# crab                 11350.0
# dorado                4877.0
# halibut               1553.0
# lingcod               2852.0
# lobster               1320.0
# opaleye                 40.0
# other                   30.0
# perch                 2091.0
# petrale sole            22.0
# red snapper            365.0
# rock sole               25.0
# rockfish            118501.0
# salmon                3730.0
# sanddab               1184.0
# sculpin              13298.0
# shark                   21.0
# sheephead             3157.0
# triggerfish             99.0
# tuna                 16289.0
# white seabass          534.0
# whitefish            31096.0
# yellowtail           11069.0
#
#
#
# released
# released                   0         1
# catch_species_gen
# 0                        1.0       NaN
# baitfish              5015.0       3.0
# barracuda            19612.0     883.0
# bass                138602.0  103222.0
# billfish                 9.0       7.0
# bonito              107001.0     155.0
# cabezon                484.0      15.0
# crab                 94398.0     230.0
# dorado               40268.0       NaN
# halibut              12976.0    2728.0
# lingcod              27764.0     211.0
# lobster               2160.0    7155.0
# opaleye                164.0       NaN
# other                  475.0      55.0
# perch                32795.0      25.0
# petrale sole           206.0       NaN
# red snapper           4792.0       NaN
# rock sole              440.0       NaN
# rockfish           1131956.0    2544.0
# salmon               21762.0     479.0
# sanddab             135110.0     216.0
# sculpin             132329.0    1201.0
# shark                   75.0      10.0
# sheephead            25428.0     471.0
# triggerfish            654.0       NaN
# tuna                123462.0       NaN
# white seabass         3672.0      17.0
# whitefish           294605.0     313.0
# yellowtail           85553.0       1.0
#
#
#
# restrictions_yn
# restrictions_yn            0        1
# catch_species_gen
# 0                        1.0      NaN
# baitfish              5018.0      NaN
# barracuda            20495.0      NaN
# bass                240716.0   1108.0
# billfish                15.0      1.0
# bonito              107002.0    154.0
# cabezon                389.0    110.0
# crab                 75823.0  18805.0
# dorado               40268.0      NaN
# halibut               9313.0   6391.0
# lingcod              18306.0   9669.0
# lobster               9315.0      NaN
# opaleye                164.0      NaN
# other                  525.0      5.0
# perch                32820.0      NaN
# petrale sole           205.0      1.0
# red snapper           4792.0      NaN
# rock sole              438.0      2.0
# rockfish           1095030.0  39470.0
# salmon                4401.0  17840.0
# sanddab             135326.0      NaN
# sculpin             133530.0      NaN
# shark                   52.0     33.0
# sheephead            25878.0     21.0
# triggerfish            654.0      NaN
# tuna                116653.0   6809.0
# white seabass         3683.0      6.0
# whitefish           294586.0    332.0
# yellowtail           84459.0   1095.0
#
#
#
# restrictions
# restrictions       up to 1 pounds  up to 10 pounds  up to 10.4 pounds  \
# catch_species_gen
# bass                          NaN            254.0                NaN
# billfish                      NaN              NaN                NaN
# bonito                        NaN              NaN                NaN
# cabezon                       NaN             30.0                NaN
# crab                          NaN              NaN                NaN
# halibut                       NaN            137.0                NaN
# lingcod                       NaN            450.0                NaN
# other                         1.0              NaN                NaN
# petrale sole                  NaN              NaN                NaN
# rock sole                     NaN              NaN                NaN
# rockfish                    107.0           2009.0                NaN
# salmon                        NaN             37.0                8.0
# shark                         NaN              NaN                NaN
# sheephead                     NaN              3.0                NaN
# tuna                          NaN              NaN                NaN
# white seabass                 NaN              NaN                NaN
# whitefish                     NaN              NaN                NaN
# yellowtail                    NaN              NaN                NaN
#
# restrictions       up to 10.5 pounds  up to 100 pounds  up to 101 pounds  \
# catch_species_gen
# bass                             NaN               NaN               NaN
# billfish                         NaN               NaN               NaN
# bonito                           NaN               NaN               NaN
# cabezon                          NaN               NaN               NaN
# crab                             NaN               NaN               NaN
# halibut                          NaN               NaN               NaN
# lingcod                          3.0               NaN               NaN
# other                            NaN               NaN               NaN
# petrale sole                     NaN               NaN               NaN
# rock sole                        NaN               NaN               NaN
# rockfish                         NaN               NaN               NaN
# salmon                           NaN               NaN               NaN
# shark                            NaN               NaN               NaN
# sheephead                        NaN               NaN               NaN
# tuna                             NaN             256.0               4.0
# white seabass                    NaN               NaN               NaN
# whitefish                        NaN               NaN               NaN
# yellowtail                       NaN               NaN               NaN
#
# restrictions       up to 102 pounds  up to 11 pounds  up to 11.6 pounds  \
# catch_species_gen
# bass                            NaN             30.0                NaN
# billfish                        NaN              NaN                NaN
# bonito                          NaN              NaN                NaN
# cabezon                         NaN              1.0                NaN
# crab                            NaN              NaN                NaN
# halibut                         NaN             68.0                NaN
# lingcod                         NaN            124.0                NaN
# other                           NaN              NaN                NaN
# petrale sole                    NaN              NaN                NaN
# rock sole                       NaN              NaN                NaN
# rockfish                        NaN            307.0                4.0
# salmon                          NaN             23.0                NaN
# shark                           NaN              NaN                NaN
# sheephead                       NaN              NaN                NaN
# tuna                            1.0              NaN                NaN
# white seabass                   NaN              NaN                NaN
# whitefish                       NaN              NaN                NaN
# yellowtail                      NaN              NaN                NaN
#
# restrictions       up to 11.75 pounds  ...  up to 8.5 pounds  up to 80 pounds  \
# catch_species_gen                      ...
# bass                              NaN  ...               NaN              NaN
# billfish                          NaN  ...               NaN              NaN
# bonito                            NaN  ...               NaN              NaN
# cabezon                           NaN  ...               NaN              NaN
# crab                              NaN  ...               NaN              NaN
# halibut                           NaN  ...               NaN              5.0
# lingcod                           NaN  ...              18.0              NaN
# other                             NaN  ...               NaN              NaN
# petrale sole                      NaN  ...               NaN              NaN
# rock sole                         NaN  ...               NaN              NaN
# rockfish                          NaN  ...             105.0              NaN
# salmon                            4.0  ...               NaN              NaN
# shark                             NaN  ...               NaN              NaN
# sheephead                         NaN  ...               NaN              NaN
# tuna                              NaN  ...               NaN            265.0
# white seabass                     NaN  ...               NaN              NaN
# whitefish                         NaN  ...               1.0              NaN
# yellowtail                        NaN  ...               NaN              NaN
#
# restrictions       up to 81 pounds  up to 85 pounds  up to 86 pounds  \
# catch_species_gen
# bass                           NaN              NaN              NaN
# billfish                       NaN              NaN              NaN
# bonito                         NaN              NaN              NaN
# cabezon                        NaN              NaN              NaN
# crab                           NaN              NaN              NaN
# halibut                        NaN              NaN              NaN
# lingcod                        NaN              NaN              NaN
# other                          NaN              NaN              NaN
# petrale sole                   NaN              NaN              NaN
# rock sole                      NaN              NaN              NaN
# rockfish                       NaN              NaN              NaN
# salmon                         NaN              NaN              NaN
# shark                          NaN              NaN              NaN
# sheephead                      NaN              NaN              NaN
# tuna                          34.0              1.0              1.0
# white seabass                  NaN              NaN              NaN
# whitefish                      NaN              NaN              NaN
# yellowtail                     NaN              NaN              NaN
#
# restrictions       up to 9 pounds  up to 9.2 pounds  up to 9.5 pounds  \
# catch_species_gen
# bass                        108.0               NaN               NaN
# billfish                      NaN               NaN               NaN
# bonito                        NaN               NaN               NaN
# cabezon                      22.0               NaN               NaN
# crab                          NaN               NaN               NaN
# halibut                      35.0               NaN               NaN
# lingcod                     118.0               NaN               3.0
# other                         NaN               NaN               NaN
# petrale sole                  NaN               NaN               NaN
# rock sole                     NaN               NaN               NaN
# rockfish                   1280.0             120.0               NaN
# salmon                        6.0               NaN               NaN
# shark                         NaN               NaN               NaN
# sheephead                     NaN               NaN               NaN
# tuna                          NaN               NaN               NaN
# white seabass                 NaN               NaN               NaN
# whitefish                     NaN               NaN               NaN
# yellowtail                    NaN               NaN               NaN
#
# restrictions       up to 90 pounds  up to 95 pounds
# catch_species_gen
# bass                           NaN              NaN
# billfish                       NaN              NaN
# bonito                         NaN              NaN
# cabezon                        NaN              NaN
# crab                           NaN              NaN
# halibut                        NaN              NaN
# lingcod                        NaN              NaN
# other                          NaN              NaN
# petrale sole                   NaN              NaN
# rock sole                      NaN              NaN
# rockfish                       NaN              NaN
# salmon                         NaN              NaN
# shark                          NaN              NaN
# sheephead                      NaN              NaN
# tuna                         177.0              9.0
# white seabass                  NaN              NaN
# whitefish                      NaN              NaN
# yellowtail                     NaN              NaN
#
# [18 rows x 200 columns]

# %% [markdown]
# ## Notes on pivoting with species:
#
# * LA caught the most barracuda, double SD's amount. Mostly SCB fish, none in WA or OR
# * SD and OC caught around 85k bass each (!), LA 45k Ventura 19k. Also appears to be a SCB fish
# * LA had the most bonito by a lot (52k vs SD 16k). Also appears to be a SCB fish
# * Bay had the most cabezon, appears to be a central coast/bay area fish. Not too many in OR, non in WA, few in SoCal getting sparser as you go south
# * almost all the crab is taken in the Bay, which is interesting. I would have thought there was more in WA/OR?
#
# * need to normalize:
#     * trip level by number of trips
#     * location possibly by population or number of trips or number of anglers
#     * possibly month by number of anglers?
#     * possibly day of week by number of trips run?
#     * I MIGHT NEED TO BUILD IN A TRIP INDICATOR (1 OR 2) ON DATA COLLECTION SCRIPT...
#
# * released and restrictions (probably rename restrictions to something else or delete altogether) don't need normalizing?

# %%
#group by boat and species?
test = df.loc[(df['location'] == 'san diego') & (df['month'] == 8)][0:100]

print(test.columns)

print(test.shape)

print(test.groupby(['boat_name', 'date2']).mean())

print(test.loc[test['boat_name'] == 'electra'])
# Out:
# Index(['location', 'boat_name', 'trip_type', 'trip_num', 'date2', 'year',
#        'month', 'day', 'day_of_week', 'anglers', 'released', 'restrictions',
#        'catch_count', 'catch_species', 'restrictions_yn', 'catch_species_gen'],
#       dtype='object')
